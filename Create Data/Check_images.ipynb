# %%
import os
os.path.abspath("P3_X.npy")
# Out:
# '/home/cloud/MRT_Data/unziped/out/P3_X.npy'

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# Pic 1

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P1_X.npy")

# %%
Y = np.load("P1_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 2

# %%
loc = np.random.randint(0, 4054)

# %%
Y = np.load("P2_Y.npy")

# %%
X = np.load("P2_X.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 3

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P3_X.npy")

# %%
Y = np.load("P3_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 4

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P4_X.npy")

# %%
Y = np.load("P4_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 5

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P5_X.npy")

# %%
Y = np.load("P5_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 6

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P6_X.npy")

# %%
Y = np.load("P6_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 7

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P7_X.npy")

# %%
Y = np.load("P7_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 8

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P8_X.npy")

# %%
Y = np.load("P8_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 9

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P9_X.npy")

# %%
Y = np.load("P9_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 10

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P10_X.npy")

# %%
Y = np.load("P10_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 11

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P11_X.npy")

# %%
Y = np.load("P11_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 12

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P12_X.npy")

# %%
Y = np.load("P12_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 13

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P13_X.npy")

# %%
Y = np.load("P13_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 14

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P14_X.npy")

# %%
Y = np.load("P14_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 15

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P15_X.npy")

# %%
Y = np.load("P15_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 16

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P16_X.npy")

# %%
Y = np.load("P16_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 17

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P17_X.npy")

# %%
Y = np.load("P17_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 18

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P18_X.npy")

# %%
Y = np.load("P18_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 19

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P19_X.npy")

# %%
Y = np.load("P19_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])

# %% [markdown]
# Pic 20

# %%
loc = np.random.randint(0, 4054)

# %%
X = np.load("P20_X.npy")

# %%
Y = np.load("P20_Y.npy")

# %%
plt.imshow(Y[loc,:,:,:])

# %%
plt.imshow(X[loc,:,:,:])
